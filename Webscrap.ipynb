# %%
import requests
from bs4 import BeautifulSoup

r= requests.get("https://ticketnew.com/movies/chennai")
c= r.content
c
# Out:
# b'<!DOCTYPE html><html lang="en"><head><meta name="next-head-count" content="9"/><script>let _N_E;</script><script async="" src="https://pwebassets.paytm.com/firefly-modules/es-module-shims/index.js"></script><script type="importmap">{"imports":{"react":"https://pwebassets.paytm.com/firefly-modules/react/18.2.0/index.js","react-dom":"https://pwebassets.paytm.com/firefly-modules/react-dom/18.2.0/index.js","storefront-h5-sdk":"https://pwebassets.paytm.com/firefly-modules/storefront-h5-sdk/3.19.3/index.js"}}</script><meta http-equiv="Content-Type" content="text/html; charset=utf-8"/><meta http-equiv="Cache-Control" content="no-cache, no-store, must-revalidate"/><meta name="p:domain_verify" content="578fa68d1988f66b6eeb98681b6646ae"/><meta name="viewport" content="width=device-width,initial-scale=1,minimum-scale=1,maximum-scale=1,user-scalable=no,viewport-fit=cover"/><link rel="preconnect" href="https://pwebassets.paytm.com"/><link rel="dns-prefetch" href="https://pwebassets.paytm.com"/>
# ...

# %%
soup = BeautifulSoup(c,"html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
all=soup.find_all("span",{"RunningMovies_moviesList__zWdfA"})
all
# Out:
# [<span class="RunningMovies_moviesList__zWdfA" style="display:block"><h1>Movies in Chennai</h1><div class="ViewMore_runningMoviesCon__Z4MlK"><div class="DesktopRunningMovie_movieCard__p5n6P"><script type="application/ld+json">{"@context":"http://schema.org","@type":"Movie","name":"Jurassic World Rebirth","url":"https://paytm.com/movies","genre":"action","image":"https://assetscdn1.paytm.com/images/cinema/Jurrasic2---6ec7c290-55a7-11f0-b09a-11c880b90aa7.jpg","inLanguage":"Tamil, English","duration":"PT134M","datePublished":"2025-07-04","releasedEvent":{"@context":"http://schema.org","@type":"PublicationEvent","startDate":"2025-07-04","location":{"@type":"Country","name":"IN"}},"aggregateRating":{"@context":"http://schema.org","@type":"AggregateRating","ratingValue":7.7,"bestRating":10,"ratingCount":87}}</script><div class="DesktopRunningMovie_runningMovie__N17Hp"><a href="/movies/jurassic-world-rebirth-movie-detail-178018"><div class="DesktopRunningMovie_imgCon__XM_UA"><img alt="Juras
# ...

# %%
len(all)
# Out:
# 1

# %%
all[0]
# Out:
# <span class="RunningMovies_moviesList__zWdfA" style="display:block"><h1>Movies in Chennai</h1><div class="ViewMore_runningMoviesCon__Z4MlK"><div class="DesktopRunningMovie_movieCard__p5n6P"><script type="application/ld+json">{"@context":"http://schema.org","@type":"Movie","name":"Jurassic World Rebirth","url":"https://paytm.com/movies","genre":"action","image":"https://assetscdn1.paytm.com/images/cinema/Jurrasic2---6ec7c290-55a7-11f0-b09a-11c880b90aa7.jpg","inLanguage":"Tamil, English","duration":"PT134M","datePublished":"2025-07-04","releasedEvent":{"@context":"http://schema.org","@type":"PublicationEvent","startDate":"2025-07-04","location":{"@type":"Country","name":"IN"}},"aggregateRating":{"@context":"http://schema.org","@type":"AggregateRating","ratingValue":7.7,"bestRating":10,"ratingCount":87}}</script><div class="DesktopRunningMovie_runningMovie__N17Hp"><a href="/movies/jurassic-world-rebirth-movie-detail-178018"><div class="DesktopRunningMovie_imgCon__XM_UA"><img alt="Jurass
# ...

# %%
all[0].find_all("div",{"class":"DesktopRunningMovie_runningMovie__N17Hp"})[0].text
# Out:
# '77%Jurassic World RebirthUA13+Tamil, English'

# %%
all[0].find_all("div",{"class":"DesktopRunningMovie_aboutTik__fD8qv"})[0].text
# Out:
# 'Book Ticket'

# %%
all[0].find_all("div",{"class":"DesktopRunningMovie_point__YtD_w"})[0].text
# Out:
# 'UA13+Tamil, English'

# %%
#all[0].find_all("href",{"class":"DesktopRunningMovie_bookTic__2d3Rl"})[0].text

# %%
'''for item in all:
    print(item.find_all("div",{"class":"DesktopRunningMovie_runningMovie__N17Hp"})[0].text)
    print(item.find_all("div",{"class":"DesktopRunningMovie_aboutTik__fD8qv"})[0].text)
    #print(item.find_all("div",{"class":"DesktopRunningMovie_point__YtD_w"})[1,10].text)
for div in item.find_all("div", {"class": "DesktopRunningMovie_point__YtD_w"})[1:]:
    print(div.text)'''
# Out:
# 'for item in all:\n    print(item.find_all("div",{"class":"DesktopRunningMovie_runningMovie__N17Hp"})[0].text)\n    print(item.find_all("div",{"class":"DesktopRunningMovie_aboutTik__fD8qv"})[0].text)\n    #print(item.find_all("div",{"class":"DesktopRunningMovie_point__YtD_w"})[1,10].text)\nfor div in item.find_all("div", {"class": "DesktopRunningMovie_point__YtD_w"})[1:]:\n    print(div.text)'

# %%
for div in item.find_all("div", {"class": "DesktopRunningMovie_point__YtD_w"})[0:]:
    print(div.text)
for div1 in item.find_all("div", {"class": "DesktopRunningMovie_runningMovie__N17Hp"})[0:]:
    print(div1.text)
for div2 in item.find_all("div", {"class": "DesktopRunningMovie_aboutTik__fD8qv"})[0:]:
    print(div2.text)
# Out:
# UA13+Tamil, English
# UA16+Hindi
# UTamil
# UA16+English, Tamil
# UATamil
# UA16+Tamil
# UA16+Tamil
# UA16+Tamil
# UA16+Tamil
# UTamil
# UA13+Tamil, English
# UA16+Malayalam
# ATamil
# UEnglish
# UA13+Telugu
# UTamil
# UATamil
# UA13+Tamil
# UA16+Tamil
# UA16+Tamil
# ATamil
# UA16+Hindi
# UEnglish
# AEnglish
# UA13+Tamil
# UA13+English
# 77%Jurassic World RebirthUA13+Tamil, English
# New ReleaseSaiyaaraUA16+Hindi
# 86%3BHKUTamil
# F1 The MovieUA16+English, Tamil
# Baashha (1995)UATamil
# New ReleaseBun Butter JamUA16+Tamil
# New ReleaseJenma NatchathiramUA16+Tamil
# New ReleaseTrendingUA16+Tamil
# New ReleaseGeviUA16+Tamil
# 78%Paranthu PoUTamil
# SupermanUA13+Tamil, English
# New ReleaseJanaki V vs State Of KeralaUA16+Malayalam
# PhoenixATamil
# New ReleaseSmurfsUEnglish
# New ReleaseJuniorUA13+Telugu
# Idhayakkani (1975)UTamil
# Ghajini (2005)UATamil
# Iravu ParavaiUA13+Tamil
# New ReleaseCentralUA16+Tamil
# New ReleaseAakiramippuUA16+Tamil
# 61%Vada Chennai (2018)ATamil
# ...

# %%
l=[]
for item in all:   #to display all movies in the website
    d={}
    d["age_language"]=item.find_all("div",{"class":"DesktopRunningMovie_point__YtD_w"})[0].text
    d["movie_name"]=item.find_all("div",{"class":"DesktopRunningMovie_runningMovie__N17Hp"})[0].text
    d["book_ticket"]=item.find_all("div",{"class":"DesktopRunningMovie_aboutTik__fD8qv"})[0].text
    l.append(d)

# %%
l
# Out:
# [{'age_language': 'UA13+Tamil, English',
#   'movie_name': '77%Jurassic World RebirthUA13+Tamil, English',
#   'book_ticket': 'Book Ticket'}]

# %%
# Get the list of elements
elements = item.find_all("div", {"class": "DesktopRunningMovie_point__YtD_w"})[0:10]

# Extract text from each element
d["age_language"] = [el.text for el in elements]

# %%
d
# Out:
# {'age_language': ['UA13+Tamil, English',
#   'UA16+Hindi',
#   'UTamil',
#   'UA16+English, Tamil',
#   'UATamil',
#   'UA16+Tamil',
#   'UA16+Tamil',
#   'UA16+Tamil',
#   'UA16+Tamil',
#   'UTamil']}

# %%
import pandas
df=pandas.DataFrame(l)

# %%
df
# Out:
#           age_language                                    movie_name  \
# 0  UA13+Tamil, English  77%Jurassic World RebirthUA13+Tamil, English
#
#    book_ticket
# 0  Book Ticket

# %%
elements = item.find_all("div", {"class": "DesktopRunningMovie_point__YtD_w"})[0:10]
elements1 = item.find_all("div", {"class": "DesktopRunningMovie_runningMovie__N17Hp"})[0:10]
elements2 = item.find_all("div", {"class": "DesktopRunningMovie_aboutTik__fD8qv"})[0:10]

d["age_language"] = [el.text for el in elements]
d["movie_name"] = [el.text for el in elements1]
d["book_ticket"] = [el.text for el in elements2]

# %%
d
# Out:
# {'age_language': ['UA13+Tamil, English',
#   'UA16+Hindi',
#   'UTamil',
#   'UA16+English, Tamil',
#   'UATamil',
#   'UA16+Tamil',
#   'UA16+Tamil',
#   'UA16+Tamil',
#   'UA16+Tamil',
#   'UTamil'],
#  'movie_name': ['77%Jurassic World RebirthUA13+Tamil, English',
#   'New ReleaseSaiyaaraUA16+Hindi',
#   '86%3BHKUTamil',
#   'F1 The MovieUA16+English, Tamil',
#   'Baashha (1995)UATamil',
#   'New ReleaseBun Butter JamUA16+Tamil',
#   'New ReleaseJenma NatchathiramUA16+Tamil',
#   'New ReleaseTrendingUA16+Tamil',
#   'New ReleaseGeviUA16+Tamil',
#   '78%Paranthu PoUTamil'],
#  'book_ticket': ['Book Ticket',
#   'Book Ticket',
#   'Book Ticket',
#   'Book Ticket',
#   'Book Ticket',
#   'Book Ticket',
#   'Book Ticket',
#   'Book Ticket',
#   'Book Ticket',
#   'Book Ticket']}

# %%
import pandas
df=pandas.DataFrame(d)

# %%
df
# Out:
#           age_language                                    movie_name  \
# 0  UA13+Tamil, English  77%Jurassic World RebirthUA13+Tamil, English
# 1           UA16+Hindi                 New ReleaseSaiyaaraUA16+Hindi
# 2               UTamil                                 86%3BHKUTamil
# 3  UA16+English, Tamil               F1 The MovieUA16+English, Tamil
# 4              UATamil                         Baashha (1995)UATamil
# 5           UA16+Tamil           New ReleaseBun Butter JamUA16+Tamil
# 6           UA16+Tamil       New ReleaseJenma NatchathiramUA16+Tamil
# 7           UA16+Tamil                 New ReleaseTrendingUA16+Tamil
# 8           UA16+Tamil                     New ReleaseGeviUA16+Tamil
# 9               UTamil                          78%Paranthu PoUTamil
#
#    book_ticket
# 0  Book Ticket
# 1  Book Ticket
# 2  Book Ticket
# 3  Book Ticket
# 4  Book Ticket
# 5  Book Ticket
# 6  Book Ticket
# 7  Book Ticket
# 8  Book Ticket
# 9  Book Ticket

# %%
df.to_csv("C:\\Users\\vadivelu\\webscrapping_ticket_now\\ticket_now_movies_list.csv")
